# %%
from pathlib import Path

import automol

geo, _ = zip(*automol.geom.from_xyz_trajectory_string(Path("opt_trj.xyz").read_text()))
automol.geom.display_trajectory(geo)
# Out:
# <div id="3dmolviewer_17731760139207573"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17731760139207573" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.3/build/3Dmol-min.js');
# }
#
# var viewer_17731760139207573 = null;
# var warn = document.getElementById("3dmolwarning_17731760139207573");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17731760139207573 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17731760139207573"),{backgroundColor:"white"});
# viewer_17731760139207573.zoomTo();
# 	viewer_17731760139207573.addModelsAsFrames(" 15\n\nC    1.899655   1.393839  -0.007247\nC    0.671341   2.263264   0.342939\nC   -0.560223   1.391982   0.009170\nC    0.001599  -0.009031   0.028433\nC    1.339571  -0.007657   0.017907\nH    2.290684   1.620107  -1.005488\nH    2.723307   1.535876   0.695770\nH    0.667012   3.217928  -0.182843\nH    0.680699   2.474468   1.413840\nH   -1.377671   1.533865   0.719676\nH   -0.963277   1.616417  -0.984775\nH   -0.616463  -0.898346  -0.002989\nH    1.958077  -0.896399  -0.024444\nO    0.863479   0.204178   3.299588\nH    0.781012   0.016599   2.345621\n 15\n\nC    1.899865   1.393699  -0.007726\nC    0.671281   2.262984   0.342937\nC   -0.560373   1.391879   0.009241\nC    0.001727  -0.008972   0.028823\nC    1.339700  -0.007772   0.018096\nH    2.290626   1.620143  -1.006038\nH    2.723770   1.535483   0.694932\nH    0.666988   3.218133  -0.181837\nH    0.680209   2.474677   1.414387\nH   -1.377493   1.533563   0.719822\nH   -0.962916   1.616619  -0.984882\nH   -0.616360  -0.898305  -0.002406\nH    1.958390  -0.896235  -0.023890\nO    0.862772   0.204442   3.298664\nH    0.780615   0.016753   2.345036","xyz");
# 	viewer_17731760139207573.setStyle({"stick": {}, "sphere": {"radius": 0.3}});
# 	viewer_17731760139207573.setBackgroundColor("0xeeeeee");
# 	viewer_17731760139207573.animate({"loop": "forward"});
# 	viewer_17731760139207573.zoomTo();
# viewer_17731760139207573.render();
# });
# </script>
