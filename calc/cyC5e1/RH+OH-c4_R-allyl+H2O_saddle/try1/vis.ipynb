# %%
from pathlib import Path

import automol

geos, _ = zip(*automol.geom.from_xyz_trajectory_string(Path("opt.hess.v006.xyz").read_text()))
automol.geom.display_trajectory(geos)
# automol.geom.display(geos[0])
# automol.geom.display(geos[2])
# automol.geom.display(geos[4])
# automol.geom.display(geos[6])
# automol.geom.display(geos[8])
# automol.geom.display(geos[10])
# Out:
# <div id="3dmolviewer_17731739215687683"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17731739215687683" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...
